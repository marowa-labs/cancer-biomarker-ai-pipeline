# %% [markdown]
# # Cancer Classification with Explainable AI
#
# This notebook explores the classification of cancer types using gene expression data from the TCGA dataset, incorporating SHAP for model explainability.
#
# ## 1. Data Acquisition and Preprocessing
# We will use the `ucimlrepo` package to fetch the dataset and perform necessary preprocessing.
# # 2. Exploratory Data Analysis (EDA)
# Visualize class distributions and gene expression patterns.
# # 3. Model Training and Evaluation
# Train a Random Forest and a Neural Network to classify cancer types.
# # 4. Explainable AI (SHAP) Analysis
# Use SHAP to interpret model predictions.
# # 5. Feature Importance and Biomarker Identification
# Extract top genes driving the classifications.

# %%
# Import necessary libraries
import pandas as pd
from ucimlrepo import fetch_ucirepo

# Fetch the dataset
# Dataset ID 401 corresponds to the Gene Expression Cancer RNA-Seq dataset
gene_expression = fetch_ucirepo(id=401)

# Access the data
X = gene_expression.data.features
y = gene_expression.data.targets

# Display the first few rows
print(X.head())
print(y.head())
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[1], line 7
#       3 from ucimlrepo import fetch_ucirepo
#       4
#       5 # Fetch the dataset
#       6 # Dataset ID 401 corresponds to the Gene Expression Cancer RNA-Seq dataset
# ----> 7 gene_expression = fetch_ucirepo(id=401)
#       8
#       9 # Access the data
#      10 X = gene_expression.data.features
#
# File ~/pyenv/lib/python3.14/site-packages/ucimlrepo/fetch.py:91, in fetch_ucirepo(name, id)
#      88 # no data URL means that the dataset cannot be imported into Python
#      89 # i.e. it does not yet have a standardized CSV file for pandas to parse
#      90 if not data_url:
# ...
